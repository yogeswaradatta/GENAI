# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENROUTER_API_KEY"]=os.getenv("OPENROUTER_API_KEY")

os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model="gemma:2b"
)

# %%
llm.invoke("what is generative AI and explain ")
# Out:
# AIMessage(content='Generative AI is a type of artificial intelligence that can create new content, such as text, images, music, and code. This content can be similar to, or completely different from, existing content. Generative AI models are trained on vast datasets of existing content and learn to generate new content that is similar in style and content.\n\nHere are some of the key characteristics of generative AI:\n\n* **Creativity:** Generative AI models can create new content that is unique and not found in existing datasets.\n* **Automating tasks:** Generative AI models can automate tasks such as content creation, transcription, and translation.\n* **Personalized content:** Generative AI models can create personalized content tailored to individual preferences.\n* **Unpredictability:** The output of generative AI models is often unpredictable, making them ideal for tasks such as image generation and language translation.\n\n**Applications of generative AI:**\n\n* **Content creation:** Generative AI models can be used to create new articles, stories, music, and other forms of content.\n* **Image generation:** Generative AI models can be used to create realistic images from scratch or from descriptions.\n* **Language translation:** Generative AI models can translate text between different languages with high accuracy.\n* **Drug discovery:** Generative AI models can be used to create new drugs and other pharmaceutical products.\n* **Customer service:** Generative AI models can be used to create chatbots and other conversational AI agents that can provide customer support.\n\n**Challenges of generative AI:**\n\n* **Bias:** Generative AI models can reflect the biases present in the data they are trained on.\n* **Ethical concerns:** Generative AI models can be used for malicious purposes, such as creating deepfakes or spreading misinformation.\n* **Transparency:** The inner workings of generative AI models can be complex and opaque, making it difficult to understand and control their outputs.\n\n**Examples of generative AI models:**\n\n* **ChatGPT:** A large language model that can generate human-like text.\n* **Midjourney:** An image generation model that can create realistic images from text descriptions.\n* **DALL-E 2:** A neural network that can generate high-quality images from text prompts.\n* **LaMDA:** A language model that can generate creative and imaginative text.\n* **Gensim:** A Python library for topic modeling and natural language processing.', additional_kwargs={}, response_metadata={'model': 'gemma:2b', 'created_at': '2026-05-08T11:24:27.5653761Z', 'done': True, 'done_reason': 'stop', 'total_duration': 13648237400, 'load_duration': 6241463600, 'prompt_eval_count': 26, 'prompt_eval_duration': 23494800, 'eval_count': 491, 'eval_duration': 6651969700, 'logprobs': None, 'model_name': 'gemma:2b', 'model_provider': 'ollama'}, id='lc_run--019e0754-bad7-7b10-a2c9-5d400179a473-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 26, 'output_tokens': 491, 'total_tokens': 517})

# %%
from langchain_core.prompt
